# %% [markdown]
# <a href="https://colab.research.google.com/github/SuvitKumar003/computer-Vision-Projects/blob/main/Image_processing_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2

# %%
img1=cv2.imread('/content/drive/MyDrive/Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/dog_backpack.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('/content/drive/MyDrive/Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/watermark_no_copy.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img2=cv2.resize(img2,(600,600))

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)
img1.shape
# Out:
# (1401, 934, 3)

# %%
x_offset=934-600
y_offset=1401-600

# %%
img2.shape
# Out:
# (600, 600, 3)

# %%
rows,col,channels=img2.shape

# %%
roi=img1[y_offset:1401,x_offset:943]

# %%
plt.imshow(roi)

# %%
img2gray = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap='gray')

# %%
img2gray = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap='gray')
