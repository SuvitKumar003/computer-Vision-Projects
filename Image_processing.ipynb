# %% [markdown]
# <a href="https://colab.research.google.com/github/SuvitKumar003/computer-Vision-Projects/blob/main/Image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread('/content/drive/MyDrive/Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2HLS )
plt.imshow(img)

# %%
img1=cv2.imread('/content/drive/MyDrive/Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/dog_backpack.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('/content/drive/MyDrive/Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/watermark_no_copy.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %% [markdown]
# BLENDING AND PASTING

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
#blenidng immage of same size

# %%
img1=cv2.resize(img1,(1200,1200))
img2=cv2.resize(img2,(1200,1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended=cv2.addWeighted(src1=img1,alpha=0.5,src2=img2,beta=0.1,gamma=0)

# %%
plt.imshow(blended)

# %%
#overrlay small iumages over large image
#no blending numpy reassignment

# %%
img1=cv2.imread('/content/drive/MyDrive/Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/dog_backpack.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread('/content/drive/MyDrive/Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/watermark_no_copy.png')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2=cv2.resize(img2,(600,600))

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
large_img=img1
small_img=img2

# %%
x_offset = 0
y_offset = 0

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

# %%
large_img[y_offset:y_end,x_offset:x_end]=small_img

# %%
plt.imshow(large_img)

# %%
cv2.rectangle(large_img,pt1=(0,0),pt2=(600,600),color=(0,255,255),thickness=10)
# Out:
# array([[[  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 50,  40,  39],
#         [ 51,  39,  39],
#         [ 52,  38,  38],
#         ...,
#         [ 73,  80,  86],
#         [ 72,  77,  81],
#         [ 70,  75,  79]],
#
#        [[ 51,  41,  40],
#         [ 52,  40,  40],
#         [ 52,  38,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 52,  42,  40],
#         [ 51,  40,  38],
#         [ 53,  39,  39],
# ...

# %%
plt.imshow(large_img)

# %%
cv2.polylines(large_img,[vertices],isClosed=True,color=(0,255,255),thickness=10)
# Out:
# array([[[  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[  0, 255, 255],
#         [  0, 255, 255],
#         [  0, 255, 255],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 50,  40,  39],
#         [ 51,  39,  39],
#         [ 52,  38,  38],
#         ...,
#         [ 73,  80,  86],
#         [ 72,  77,  81],
#         [ 70,  75,  79]],
#
#        [[ 51,  41,  40],
#         [ 52,  40,  40],
#         [ 52,  38,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 52,  42,  40],
#         [ 51,  40,  38],
#         [ 53,  39,  39],
# ...

# %%
plt.imshow(large_img)

# %%
vertices=np.array([ [100,200], [600,600] , [600,200] , [0,0] ],dtype=np.int32)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
vertices.reshape((-1,1,2))
# Out:
# array([[[100, 200]],
#
#        [[600, 600]],
#
#        [[600, 200]],
#
#        [[  0,   0]]], dtype=int32)

# %%
blank_img=np.zeros(shape=(600,600,3),dtype=np.int32)

# %%
plt.imshow(blank_img)

# %%
cv2.circle(blank_img,center=(300,300),radius=100,color=(125,211,65),thickness=10)
cv2.line(blank_img,pt1=(100,100),pt2=(500,500),color=(124,255,0),thickness=10)
vertices=np.array([[100,100],[200,200],[300,300],[100,400]])
vertices=vertices.reshape((-1,1,2))
cv2.polylines(blank_img,[vertices],isClosed=True,color=(124,255,99),thickness=10)
plt.imshow(blank_img)

# %%
blank_img=np.zeros(shape=(600,600,3),dtype=np.int32)
vertices=np.array([[100,100],[400,400],[200,200],[300,300]])
vertices=vertices.reshape((-1,1,2))
cv2.polylines(blank_img,[vertices],isClosed=True,color=(124,255,99),thickness=10)
plt.imshow(blank_img)
